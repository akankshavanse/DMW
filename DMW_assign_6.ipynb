# %%
#import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes = True)

# %%
#read pima indian diabetes dataset using pandas
pima = pd.read_csv('/content/diabetes.csv')

# %%
#print first five rows of dataset
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#print shape
pima.shape
# Out:
# (768, 9)

# %%
#print datatypes
pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#check if null values any
pima.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#how many people have diabetes and how many of them do not
pima['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
#plotting bar plot
plt.figure(figsize=(10,7))
sns.set(font_scale = 1.5)
sns.countplot(x = 'Outcome', data=pima, palette="Set2")
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')

# %%
#plotting histogram
pima.hist(figsize = (20,16),grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed53e1c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed4e7610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed514a30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed4c3e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed47c280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed4285b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed4286a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed455af0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc7ed3c02e0>]],
#       dtype=object)

# %%
#plotting boxplot to identify outliers
pima.plot(kind= 'box' , subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(15,15))
sns.set(font_scale = 1.5)

# %%
# Plotting the pie chart
plt.figure(figsize=(8,8))
pieC = pima['Outcome'].value_counts()
explode = (0.05, 0)
colors = ['moccasin', 'coral']
labels = ['0 - Non Diabetic', '1 - Diabetic']
sns.set(font_scale = 1.5)
plt.pie(pieC, labels = ('0 - Non Diabetic', '1 - Diabetic'), autopct = "%.2f%%", explode = explode, colors = colors)
plt.legend(labels, loc = 'lower left')

# %%
corr=pima.corr()

# %%
#plottting heatmap
plt.figure(figsize=(15,10))
sns.set(font_scale = 1.5)
sns.heatmap(corr, annot = True, cmap = 'ocean', vmin = -1, vmax = 1, linecolor='white', linewidths= 1)

# %%
#plotting scatterplot
p=pima.Pregnancies
o=pima.Outcome
plt.scatter(p,o)
plt.show()
